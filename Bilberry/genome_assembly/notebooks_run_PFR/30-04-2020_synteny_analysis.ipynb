# %% [markdown]
# # Synteny analysis between bilberry and blueberry genomes

# %% [markdown]
# ## 1. input file path

# %%
BLUEBERRY_GENOME=/workspace/ComparativeDataSources/Vaccinium_corymbosum/NCSU_VcaeV1.3/VcaeV1.3.fa
BB_DIP_P0=/workspace/ComparativeDataSources/Vaccinium_corymbosum/NCSU_VcaeV1.3/VcaeV1.3.p0.fa
CHR=/workspace/hraczw/github/GA/Bilberry_genome/012.HiC.ALLHIC/groups.asm.fasta
SCAFF_SHASTA=/workspace/hraczw/github/GA/Bilberry_genome/100.all.assemblies/Shasta_pilon-1_corrected_pilon-i2_corrected.ml1000.fasta.fasta
SCAFF_FLYE=/workspace/hraczw/github/GA/Bilberry_genome/100.all.assemblies/Flye_pilon-1_corrected_pilon-i2_corrected.ml1000.fasta.fasta

SCAFF_SHASTA_RACON_I1=/workspace/hraczw/github/GA/Bilberry_genome/0101.Contamination.analysis/Shasta_racon_i1_pilon-2.noBacteria.ml1000.fasta
SCAFF_SHASTA_RACON_I3=/workspace/hraczw/github/GA/Bilberry_genome/0101.Contamination.analysis/Shasta_racon_i3_pilon-2.noBacteria.ml1000.fasta
BLUEBERRY_GENOME_MSU=/output/genomic/plant/Vaccinium/corymbosum/Blueberry_genome_MSU_tetraploid_18012019/BB_genome_10kbUp_renamed.haplotype_1.fasta

# %%
CHR_V1=/workspace/hraczw/github/GA/Bilberry_genome/017.Chr.Ali/bilberry_chrs_shasta_r1_p2_clean.fasta

# %%
CHR_V2=/workspace/hraczw/github/GA/Bilberry_genome/017.Chr.Ali/bilberry_chrs_shasta_r1_p2_clean.v2.fasta

# %%
CHR_OFFICIAL_V1=/output/genomic/plant/Vaccinium/myrtillus/Genome/Assembly/bilberry_chr01-12.fasta

# %%
WORKDIR=/workspace/hraczw/github/GA/Bilberry_genome/014.synteny.check

# %% [markdown]
# ## 2. mapping and synteny

# %%
mkdir 014.synteny.check

# %% [markdown]
# ### 2.1 mapping to combined diploid genome

# %%
bsub -J nucmer \
-m wkoppb50 \
-n 10 \
-o 014.synteny.check/nucmer_chr_shasta.out \
-e 014.synteny.check/nucmer_chr_shasta.err \
"/workspace/hrarnc/software/mummer-4.0.0beta2/bin/nucmer \
--mum \
--prefix=chr_shasta \
-t 10 \
$BLUEBERRY_GENOME $CHR"
# Out:
# Job <700460> is submitted to default queue <lowpriority>.

# %%
bsub -J nucmer \
-m wkoppb50 \
-n 10 \
-o 014.synteny.check/nucmer_shasta.out \
-e 014.synteny.check/nucmer_shasta.err \
"/workspace/hrarnc/software/mummer-4.0.0beta2/bin/nucmer \
--mum \
--prefix=shasta \
-t 10 \
$BLUEBERRY_GENOME $SCAFF_SHASTA"
# Out:
# Job <700461> is submitted to default queue <lowpriority>.

# %%
bsub -J nucmer \
-m wkoppb50 \
-n 10 \
-o 014.synteny.check/nucmer_flye.out \
-e 014.synteny.check/nucmer_flye.err \
"/workspace/hrarnc/software/mummer-4.0.0beta2/bin/nucmer \
--mum \
--prefix=flye \
-t 10 \
$BLUEBERRY_GENOME $SCAFF_FLYE"
# Out:
# Job <700463> is submitted to default queue <lowpriority>.

# %% [markdown]
# ### 2.2 mapping to phased p0 genome

# %%
bsub -J nucmer \
-m wkoppb50 \
-n 20 \
-o 014.synteny.check/nucmer_chr_shasta_p0.out \
-e 014.synteny.check/nucmer_chr_shasta_p0.err \
"/workspace/hrarnc/software/mummer-4.0.0beta2/bin/nucmer \
--mum \
--prefix=chr_shasta_p0 \
-t 20 \
$BB_DIP_P0 $CHR"
# Out:
# Job <717505> is submitted to default queue <lowpriority>.

# %%
bsub -J nucmer \
-m wkoppb50 \
-n 20 \
-o 014.synteny.check/nucmer_shasta_p0.out \
-e 014.synteny.check/nucmer_shasta_p0.err \
"/workspace/hrarnc/software/mummer-4.0.0beta2/bin/nucmer \
--mum \
--prefix=shasta_p0 \
-t 20 \
$BB_DIP_P0 $SCAFF_SHASTA"
# Out:
# Job <717506> is submitted to default queue <lowpriority>.

# %%
bsub -J nucmer \
-m wkoppb50 \
-n 20 \
-o 014.synteny.check/nucmer_flye_p0.out \
-e 014.synteny.check/nucmer_flye_p0.err \
"/workspace/hrarnc/software/mummer-4.0.0beta2/bin/nucmer \
--mum \
--prefix=flye_p0 \
-t 20 \
$BB_DIP_P0 $SCAFF_FLYE"
# Out:
# Job <717507> is submitted to default queue <lowpriority>.

# %%
bsub -J nucmer \
-m wkoppb50 \
-n 10 \
-o 014.synteny.check/nucmer_scaff_shasta_racon_i1.out \
-e 014.synteny.check/nucmer_scaff_shasta_racon_i1.err \
"/workspace/hrarnc/software/mummer-4.0.0beta2/bin/nucmer \
--mum \
--prefix=scaff_shasta_racon_i1 \
-t 10 \
$BLUEBERRY_GENOME_MSU $SCAFF_SHASTA_RACON_I1"
# Out:
# Job <253732> is submitted to default queue <lowpriority>.

# %%
bsub -J nucmer \
-m wkoppb50 \
-n 10 \
-o 014.synteny.check/nucmer_scaff_shasta_racon_i1_againstDip.out \
-e 014.synteny.check/nucmer_scaff_shasta_racon_i1_againstDip.err \
"/workspace/hrarnc/software/mummer-4.0.0beta2/bin/nucmer \
--mum \
--prefix=scaff_shasta_racon_i1_againstDip \
-t 10 \
$BLUEBERRY_GENOME $SCAFF_SHASTA_RACON_I1"
# Out:
# Job <255031> is submitted to default queue <lowpriority>.

# %%
bsub -J nucmer \
-m wkoppb50 \
-n 10 \
-o 014.synteny.check/nucmer_scaff_shasta_racon_i3.out \
-e 014.synteny.check/nucmer_scaff_shasta_racon_i3.err \
"/workspace/hrarnc/software/mummer-4.0.0beta2/bin/nucmer \
--mum \
--prefix=scaff_shasta_racon_i3 \
-t 10 \
$BLUEBERRY_GENOME_MSU $SCAFF_SHASTA_RACON_I3"
# Out:
# Job <253733> is submitted to default queue <lowpriority>.

# %%
bsub -J nucmer \
-m wkoppb50 \
-n 10 \
-o 014.synteny.check/nucmer_contig_chrs.out \
-e 014.synteny.check/nucmer_contig_chrs.err \
"/workspace/hrarnc/software/mummer-4.0.0beta2/bin/nucmer \
--mum \
--prefix=contig_chrs \
-t 10 \
$BLUEBERRY_GENOME_MSU $CTG_CHR"
# Out:
# Job <255530> is submitted to default queue <lowpriority>.

# %%
bsub -J nucmer \
-m wkoppb50 \
-n 10 \
-o 014.synteny.check/nucmer_contig_chrs_v1.out \
-e 014.synteny.check/nucmer_contig_chrs_v1.err \
"/workspace/hrarnc/software/mummer-4.0.0beta2/bin/nucmer \
--mum \
--prefix=chrs_v1_againstMSU \
-t 10 \
$BLUEBERRY_GENOME_MSU $CHR_V1"
# Out:
# Job <406882> is submitted to default queue <lowpriority>.

# %%
bsub -J nucmer \
-m wkoppb50 \
-n 10 \
-o 014.synteny.check/nucmer_contig_chrs_v2.out \
-e 014.synteny.check/nucmer_contig_chrs_v2.err \
"/workspace/hrarnc/software/mummer-4.0.0beta2/bin/nucmer \
--mum \
--prefix=chrs_v2_againstMSU \
-t 10 \
$BLUEBERRY_GENOME_MSU $CHR_V2"
# Out:
# Job <411209> is submitted to default queue <lowpriority>.

# %%
bsub -J nucmer \
-m wkoppb50 \
-n 10 \
-o 014.synteny.check/nucmer_contig_chrs_official_v1.out \
-e 014.synteny.check/nucmer_contig_chrs_official_v1.err \
"/workspace/hrarnc/software/mummer-4.0.0beta2/bin/nucmer \
--mum \
--prefix=chrs_official_v1_againstMSU \
-t 10 \
$BLUEBERRY_GENOME_MSU $CHR_OFFICIAL_V1"
# Out:
# Job <433516> is submitted to default queue <lowpriority>.

# %%
bsub -J nucmer \
-m wkoppb50 \
-n 10 \
-o 014.synteny.check/nucmer_scaff_shasta_racon_i3_againstDip.out \
-e 014.synteny.check/nucmer_scaff_shasta_racon_i3_againstDip.err \
"/workspace/hrarnc/software/mummer-4.0.0beta2/bin/nucmer \
--mum \
--prefix=scaff_shasta_racon_i3_againstDip \
-t 10 \
$BLUEBERRY_GENOME $SCAFF_SHASTA_RACON_I3"
# Out:
# Job <255032> is submitted to default queue <lowpriority>.

# %%
mv *.delta 014.synteny.check

# %%
bsub -J nucmer \
-o 014.synteny.check/dnadiff_chr_shasta_p0.out \
-e 014.synteny.check/dnadiff_chr_shasta_p0.err \
"/workspace/hrarnc/software/mummer-4.0.0beta2/bin/dnadiff \
-d 014.synteny.check/chr_shasta_p0.delta \
-p 014.synteny.check/chr_shasta_p0"
# Out:
# Job <738928> is submitted to default queue <lowpriority>.

# %%
bsub -J nucmer \
-o 014.synteny.check/dnadiff_shasta_p0.out \
-e 014.synteny.check/dnadiff_shasta_p0.err \
"/workspace/hrarnc/software/mummer-4.0.0beta2/bin/dnadiff \
-d 014.synteny.check/shasta_p0.delta \
-p 014.synteny.check/shasta_p0"
# Out:
# Job <738929> is submitted to default queue <lowpriority>.

# %%
bsub -J nucmer \
-o 014.synteny.check/dnadiff_flye_p0.out \
-e 014.synteny.check/dnadiff_flye_p0.err \
"/workspace/hrarnc/software/mummer-4.0.0beta2/bin/dnadiff \
-d 014.synteny.check/flye_p0.delta \
-p 014.synteny.check/flye_p0"
# Out:
# Job <738930> is submitted to default queue <lowpriority>.

# %% [markdown]
# #### 2.2.1 filter based on identity and alignment length
# * alignment length: 10k
# * identity: 80 / 70

# %%
/workspace/hrarnc/software/mummer-4.0.0beta2/bin/delta-filter -h
# Out:
# USAGE: /workspace/hrarnc/software/mummer-4.0.0beta2/bin/delta-filter  [options]  <deltafile>
#
# -1            1-to-1 alignment allowing for rearrangements
#               (intersection of -r and -q alignments)
# -g            1-to-1 global alignment not allowing rearrangements
# -h            Display help information
# -i float      Set the minimum alignment identity [0, 100], default 0
# -l int        Set the minimum alignment length, default 0
# -m            Many-to-many alignment allowing for rearrangements
#               (union of -r and -q alignments)
# -q            Maps each position of each query to its best hit in
#               the reference, allowing for reference overlaps
# -r            Maps each position of each reference to its best hit
#               in the query, allowing for query overlaps
# -u float      Set the minimum alignment uniqueness, i.e. percent of
#               the alignment matching to unique reference AND query
# ...

# %%
bsub -J filter \
-o $WORKDIR/filter_chr_shasta_p0.out \
-e $WORKDIR/filter_chr_shasta_p0.err \
"/workspace/hrarnc/software/mummer-4.0.0beta2/bin/delta-filter \
-i 80 \
-l 10000 \
-m \
$WORKDIR/chr_shasta_p0.delta > $WORKDIR/chr_shasta_p0.i80.l10k.delta"
# Out:
# Job <738931> is submitted to default queue <lowpriority>.

# %%
bsub -J filter \
-o $WORKDIR/filter_shasta_p0.out \
-e $WORKDIR/filter_shasta_p0.err \
"/workspace/hrarnc/software/mummer-4.0.0beta2/bin/delta-filter \
-i 80 \
-l 10000 \
-m \
$WORKDIR/shasta_p0.delta > $WORKDIR/shasta_p0.i80.l10k.delta"
# Out:
# Job <738944> is submitted to default queue <lowpriority>.

# %%
bsub -J filter \
-o $WORKDIR/filter_flye_p0.out \
-e $WORKDIR/filter_flye_p0.err \
"/workspace/hrarnc/software/mummer-4.0.0beta2/bin/delta-filter \
-i 80 \
-l 10000 \
-m \
$WORKDIR/flye_p0.delta > $WORKDIR/flye_p0.i80.l10k.delta"
# Out:
# Job <738945> is submitted to default queue <lowpriority>.

# %%
bsub -J filter \
-o $WORKDIR/filter_shasta_p0.i80.l5k.out \
-e $WORKDIR/filter_shasta_p0.i80.l5k.err \
"/workspace/hrarnc/software/mummer-4.0.0beta2/bin/delta-filter \
-i 80 \
-l 5000 \
-m \
$WORKDIR/shasta_p0.delta > $WORKDIR/shasta_p0.i80.l5k.delta"
# Out:
# Job <232247> is submitted to default queue <lowpriority>.

# %%
bsub -J filter \
-o $WORKDIR/filter_shasta_p0.i80.l2k.out \
-e $WORKDIR/filter_shasta_p0.i80.l2k.err \
"/workspace/hrarnc/software/mummer-4.0.0beta2/bin/delta-filter \
-i 80 \
-l 2000 \
-m \
$WORKDIR/shasta_p0.delta > $WORKDIR/shasta_p0.i80.l2k.delta"
# Out:
# Job <232248> is submitted to default queue <lowpriority>.

# %%
bsub -J filter \
-o $WORKDIR/filter_nucmer_scaff_shasta_racon_i1.i80.l10k.out \
-e $WORKDIR/filter_nucmer_scaff_shasta_racon_i1.i80.l10k.err \
"/workspace/hrarnc/software/mummer-4.0.0beta2/bin/delta-filter \
-i 80 \
-l 10000 \
-m \
$WORKDIR/scaff_shasta_racon_i1.delta > $WORKDIR/scaff_shasta_racon_i1.i80.l10k.delta"
# Out:
# Job <255043> is submitted to default queue <lowpriority>.

# %%
bsub -J filter \
-o $WORKDIR/filter_chrs_v1_againstMSU.i80.l5k.out \
-e $WORKDIR/filter_chrs_v1_againstMSU.i80.l5k.err \
"/workspace/hrarnc/software/mummer-4.0.0beta2/bin/delta-filter \
-i 80 \
-l 5000 \
-m \
$WORKDIR/chrs_v1_againstMSU.delta > $WORKDIR/chrs_v1_againstMSU.i80.l5k.delta"
# Out:
# Job <407484> is submitted to default queue <lowpriority>.

# %%
bsub -J filter \
-o $WORKDIR/filter_chrs_v1_againstMSU.i80.l10k.out \
-e $WORKDIR/filter_chrs_v1_againstMSU.i80.l10k.err \
"/workspace/hrarnc/software/mummer-4.0.0beta2/bin/delta-filter \
-i 80 \
-l 10000 \
-m \
$WORKDIR/chrs_v1_againstMSU.delta > $WORKDIR/chrs_v1_againstMSU.i80.l10k.delta"
# Out:
# Job <407554> is submitted to default queue <lowpriority>.

# %%
bsub -J filter \
-o $WORKDIR/filter_chrs_v2_againstMSU.i80.l10k.out \
-e $WORKDIR/filter_chrs_v2_againstMSU.i80.l10k.err \
"/workspace/hrarnc/software/mummer-4.0.0beta2/bin/delta-filter \
-i 80 \
-l 10000 \
-m \
$WORKDIR/chrs_v2_againstMSU.delta > $WORKDIR/chrs_v2_againstMSU.i80.l10k.delta"
# Out:
# Job <411280> is submitted to default queue <lowpriority>.

# %%
bsub -J filter \
-o $WORKDIR/filter_chrs_official_v1_againstMSU.i80.l10k.out \
-e $WORKDIR/filter_chrs_official_v1_againstMSU.i80.l10k.err \
"/workspace/hrarnc/software/mummer-4.0.0beta2/bin/delta-filter \
-i 80 \
-l 10000 \
-m \
$WORKDIR/chrs_official_v1_againstMSU.delta > $WORKDIR/chrs_official_v1_againstMSU.i80.l10k.delta"
# Out:
# Job <433520> is submitted to default queue <lowpriority>.

# %%
$WORKDIR
# Out:
# bash: /workspace/hraczw/github/GA/Bilberry_genome/014.synteny.check: Is a directory
# : 126

# %%
bsub -J filter \
-o $WORKDIR/filter_nucmer_scaff_shasta_racon_i3.i80.l10k.out \
-e $WORKDIR/filter_nucmer_scaff_shasta_racon_i3.i80.l10k.err \
"/workspace/hrarnc/software/mummer-4.0.0beta2/bin/delta-filter \
-i 80 \
-l 10000 \
-m \
$WORKDIR/scaff_shasta_racon_i3.delta > $WORKDIR/scaff_shasta_racon_i3.i80.l10k.delta"

# %% [markdown]
# #### 2.2.2 generate synteny graph

# %%
bsub -J graph \
-o $WORKDIR/graph.i80.l10k.out \
-e $WORKDIR/graph.i80.l10k.err \
"/workspace/hrarnc/software/mummer-4.0.0beta2/bin/mummerplot \
--large \
--png \
$WORKDIR/chr_shasta_p0.i80.l10k.delta \
-R $BB_DIP_P0 \
-Q $CHR \
--filter \
--layout \
-p $WORKDIR/chr_shasta_p0.i80.l10k.graph"
# Out:
# Job <738935> is submitted to default queue <lowpriority>.

# %%
bsub -J graph \
-o $WORKDIR/graph.i80.l2k.shasta.out \
-e $WORKDIR/graph.i80.l2k.shasta.err \
"/workspace/hrarnc/software/mummer-4.0.0beta2/bin/mummerplot \
--large \
--png \
$WORKDIR/shasta_p0.i80.l2k.delta \
-R $BB_DIP_P0 \
-Q $SCAFF_SHASTA \
--filter \
--layout \
-p $WORKDIR/shasta_p0.i80.l2k.graph"
# Out:
# Job <232250> is submitted to default queue <lowpriority>.

# %%
bsub -J graph \
-o $WORKDIR/graph.i80.l10k.flye.out \
-e $WORKDIR/graph.i80.l10k.flye.err \
"/workspace/hrarnc/software/mummer-4.0.0beta2/bin/mummerplot \
--large \
--png \
$WORKDIR/flye_p0.i80.l10k.delta \
-R $BB_DIP_P0 \
-Q $SCAFF_FLYE \
--filter \
--layout \
-p $WORKDIR/flye_p0.i80.l10k.graph"
# Out:
# Job <738950> is submitted to default queue <lowpriority>.

# %%
cat $WORKDIR/flye_p0.i80.l10k.graph.png | display

# %%
cat $WORKDIR/shasta_p0.i80.l10k.graph.png | display

# %%
cat $WORKDIR/chr_shasta_p0.i80.l10k.graph.png | display

# %%
bsub -J graph \
-o $WORKDIR/graph.nucmer_scaff_shasta_racon_i1.i80.l5k.out \
-e $WORKDIR/graph.nucmer_scaff_shasta_racon_i1.i80.l5k.err \
"/workspace/hrarnc/software/mummer-4.0.0beta2/bin/mummerplot \
--large \
--png \
$WORKDIR/scaff_shasta_racon_i1.i80.l5k.delta \
-R $BLUEBERRY_GENOME_MSU \
-Q $SCAFF_SHASTA_RACON_I1 \
--filter \
--layout \
-p $WORKDIR/scaff_shasta_racon_i1.i80.l5k.graph"
# Out:
# Job <254079> is submitted to default queue <lowpriority>.

# %%
cat $WORKDIR/scaff_shasta_racon_i1.i80.l5k.graph.png | display

# %%
bsub -J graph \
-o $WORKDIR/graph.nucmer_scaff_shasta_racon_i1.i80.l10k.out \
-e $WORKDIR/graph.nucmer_scaff_shasta_racon_i1.i80.l10k.err \
"/workspace/hrarnc/software/mummer-4.0.0beta2/bin/mummerplot \
--large \
--png \
$WORKDIR/scaff_shasta_racon_i1.i80.l10k.delta \
-R $BLUEBERRY_GENOME_MSU \
-Q $SCAFF_SHASTA_RACON_I1 \
--filter \
--layout \
-p $WORKDIR/scaff_shasta_racon_i1.i80.l10k.graph"
# Out:
# Job <255045> is submitted to default queue <lowpriority>.

# %%
cat $WORKDIR/scaff_shasta_racon_i1.i80.l10k.graph.png | display

# %%
bsub -J graph \
-o $WORKDIR/graph.nucmer_scaff_shasta_racon_i3.i80.l5k.out \
-e $WORKDIR/graph.nucmer_scaff_shasta_racon_i3.i80.l5k.err \
"/workspace/hrarnc/software/mummer-4.0.0beta2/bin/mummerplot \
--large \
--png \
$WORKDIR/scaff_shasta_racon_i3.i80.l5k.delta \
-R $BLUEBERRY_GENOME_MSU \
-Q $SCAFF_SHASTA_RACON_I3 \
--filter \
--layout \
-p $WORKDIR/scaff_shasta_racon_i3.i80.l5k.graph"
# Out:
# Job <254080> is submitted to default queue <lowpriority>.

# %%
cat $WORKDIR/scaff_shasta_racon_i3.i80.l5k.graph.png | display

# %%
bsub -J graph \
-o $WORKDIR/graph.nucmer_scaff_shasta_racon_i3.i80.l10k.out \
-e $WORKDIR/graph.nucmer_scaff_shasta_racon_i3.i80.l10k.err \
"/workspace/hrarnc/software/mummer-4.0.0beta2/bin/mummerplot \
--large \
--png \
$WORKDIR/scaff_shasta_racon_i3.i80.l10k.delta \
-R $BLUEBERRY_GENOME_MSU \
-Q $SCAFF_SHASTA_RACON_I3 \
--filter \
--layout \
-p $WORKDIR/scaff_shasta_racon_i3.i80.l10k.graph"
# Out:
# Job <255046> is submitted to default queue <lowpriority>.

# %%
cat $WORKDIR/scaff_shasta_racon_i3.i80.l10k.graph.png | display

# %%
bsub -J graph \
-o $WORKDIR/graph.chrs_v1_againstMSU.i80.l5k.out \
-e $WORKDIR/graph.chrs_v1_againstMSU.i80.l5k.err \
"/workspace/hrarnc/software/mummer-4.0.0beta2/bin/mummerplot \
--large \
--png \
$WORKDIR/chrs_v1_againstMSU.i80.l5k.delta \
-R $BLUEBERRY_GENOME_MSU \
-Q $CHR_V1 \
--filter \
--layout \
-p $WORKDIR/chrs_v1_againstMSU.i80.l5k.graph"
# Out:
# Job <407563> is submitted to default queue <lowpriority>.

# %%
cat $WORKDIR/chrs_v1_againstMSU.i80.l5k.graph.png | display

# %%
bsub -J graph \
-o $WORKDIR/graph.chrs_v1_againstMSU.i80.l10k.out \
-e $WORKDIR/graph.chrs_v1_againstMSU.i80.l10k.err \
"/workspace/hrarnc/software/mummer-4.0.0beta2/bin/mummerplot \
--large \
--png \
$WORKDIR/chrs_v1_againstMSU.i80.l10k.delta \
-R $BLUEBERRY_GENOME_MSU \
-Q $CHR_V1 \
--filter \
--layout \
-p $WORKDIR/chrs_v1_againstMSU.i80.l10k.graph"
# Out:
# Job <407564> is submitted to default queue <lowpriority>.

# %%
cat $WORKDIR/chrs_v1_againstMSU.i80.l10k.graph.png | display

# %%
$WORKDIR/chrs_v1_againstMSU.i80.l10k.graph.png
# Out:
# bash: /workspace/hraczw/github/GA/Bilberry_genome/014.synteny.check/chrs_v1_againstMSU.i80.l10k.graph.png: Permission denied
# : 126

# %%
bsub -J graph \
-o $WORKDIR/graph.chrs_v2_againstMSU.i80.l10k.out \
-e $WORKDIR/graph.chrs_v2_againstMSU.i80.l10k.err \
"/workspace/hrarnc/software/mummer-4.0.0beta2/bin/mummerplot \
--large \
--png \
$WORKDIR/chrs_v2_againstMSU.i80.l10k.delta \
-R $BLUEBERRY_GENOME_MSU \
-Q $CHR_V2 \
--filter \
--layout \
-p $WORKDIR/chrs_v2_againstMSU.i80.l10k.graph"
# Out:
# Job <411287> is submitted to default queue <lowpriority>.

# %%
cat $WORKDIR/chrs_v2_againstMSU.i80.l10k.graph.png | display

# %%
$WORKDIR
# Out:
# bash: /workspace/hraczw/github/GA/Bilberry_genome/014.synteny.check: Is a directory
# : 126

# %%
bsub -J graph \
-o $WORKDIR/graph.chrs_official_v1_againstMSU.i80.l10k.out \
-e $WORKDIR/graph.chrs_official_v1_againstMSU.i80.l10k.err \
"/workspace/hrarnc/software/mummer-4.0.0beta2/bin/mummerplot \
--large \
--png \
$WORKDIR/chrs_official_v1_againstMSU.i80.l10k.delta \
-R $BLUEBERRY_GENOME_MSU \
-Q $CHR_OFFICIAL_V1 \
--filter \
--layout \
-p $WORKDIR/chrs_official_v1_againstMSU.i80.l10k.graph"
# Out:
# Job <433521> is submitted to default queue <lowpriority>.

# %%
cat $WORKDIR/chrs_official_v1_againstMSU.i80.l10k.graph.png | display
