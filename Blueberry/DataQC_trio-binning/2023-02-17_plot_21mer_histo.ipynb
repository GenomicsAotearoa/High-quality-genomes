# %%
# load libraries
library(readr)
library(dplyr)
library(ggplot2)
# Out:
# Attaching package: 'dplyr'
#
#
# The following objects are masked from 'package:stats':
#
#     filter, lag
#
#
# The following objects are masked from 'package:base':
#
#     intersect, setdiff, setequal, union

# %%
v <- c('count','M')
# histobj <- read_delim("/powerplant/workspace/hrasrb/Blueberry_trio/data_qc/illumina/M7_S1_L001_R1_001.fastq.gz_21mer_histogram.out", delim = " ", col_names = v)
# histobj <- read_delim("/powerplant/workspace/hrasrb/Blueberry_trio/data_qc/illumina/M7_S1_L004_R1_001.fastq.gz_21mer_histogram.out", delim = " ", col_names = v)
# histobj <- read_delim("/powerplant/workspace/hrasrb/Blueberry_trio/data_qc/illumina/combined_21mer_histogram.out", delim = " ", col_names = v)
histobj <- read_delim("/powerplant/workspace/hrasrb/Blueberry_trio/data_qc/illumina/Nui_S2_L001_R1_001.fastq.gz_21mer_histogram.out", delim = " ", col_names = v)
# histobj <- read_delim("/powerplant/workspace/hrasrb/Blueberry_trio/data_qc/hifi/m64136_221113_041854/03.kmer_analysis/m64136_221113_041854Histogram.out", delim = " ", col_names = v)
# histobj <- read_delim("/powerplant/workspace/hrasrb/Blueberry_trio/data_qc/hifi/m64136_221114_133241/03.kmer_analysis/m64136_221114_133241Histogram.out", delim = " ", col_names = v)
# Out:
# Parsed with column specification:
# cols(
#   count = col_double(),
#   M = col_double()
# )

# %%
summary(histobj)
# Out:
#      count             M
#  Min.   :    1   Min.   :        1
#  1st Qu.: 2501   1st Qu.:       10
#  Median : 5001   Median :       21
#  Mean   : 5001   Mean   :   164932
#  3rd Qu.: 7501   3rd Qu.:      103
#  Max.   :10001   Max.   :734699517

# %%
head(histobj)
# Out:
#   count M
# 1 1     734699517
# 2 2     149823887
# 3 3      39316351
# 4 4      25844036
# 5 5      26141067
# 6 6      29464668

# %%
tail(histobj)
# Out:
#   count M
# 1  9996     34
# 2  9997     30
# 3  9998     26
# 4  9999     26
# 5 10000     25
# 6 10001 137655

# %%
i <- ggplot(histobj, aes(count, M))
i <- i + geom_point()
i
# Out:
# plot without title

# %%
i + coord_cartesian(xlim=c(0,200), ylim = c(0, 50000000 )) + xlab("Frequency of k-mers (count)") + ylab("Number of k-mers (M)")
# Out:
# plot without title

# %%
i <- ggplot(histobj, aes(count, M))
t <- i + geom_line()
t
# Out:
# plot without title

# %%
#t <- t + coord_cartesian(xlim=c(0,200), ylim = c(0, 970000000)) + xlab("Frequency of k-mers (count)") + ylab("Number of k-mers (M)")
t <- t + coord_cartesian(xlim=c(0,150), ylim = c(0, 35000000)) + xlab("Frequency of k-mers (count)") + ylab("Number of k-mers (M)")
t 
# t + geom_segment(x = 8, y = -2000000, xend = 8, yend = 34000000, linetype = "dashed", color = "magenta", size = 0.2) +
#     geom_segment(x = 33, y = -2000000, xend = 33, yend = 10000000, linetype = "dashed", color = "blue", size = 0.2) 
# +
# geom_segment(x = 43, y = -2000000, xend = 43, yend = 2594012, linetype = "dashed", color = "red", size = 0.2) +
# geom_segment(x = 140, y = -2000000, xend = 140, yend = 1440842, linetype = "dashed", color = "green", size = 0.2)
# Out:
# plot without title

# %%
ggsave(plot = t,'/powerplant/workspace/hrasrb/Blueberry_trio/data_qc/illumina/Nui_S2_L001_R1_001.fastq.gz_21mer_histogram.png', width=8.27, height= 10)
# ggsave(plot = t,'/powerplant/workspace/hrasrb/Blueberry_trio/data_qc/hifi/m64136_221113_041854/m64136_221113_041854_21mer_histogram.png', width=8.27, height= 10)

# %%
dev.off()
# Out:
# null device
#           1
