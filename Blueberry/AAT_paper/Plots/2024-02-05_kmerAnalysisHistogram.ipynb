# %% [markdown]
# # Kmer analysis - histogram

# %%
getwd()
# Out:
# [1] "/powerplant/workspace/hraczw/github/bioinf_blueberry_trio"

# %%
df_M7 = read.table("/workspace/hrasrb/Blueberry_trio/data_qc/illumina/combined_21mer_histogram.out", header = FALSE)

# %%
head(df_M7)
# Out:
#   V1 V2
# 1 1  2482146436
# 2 2   304399501
# 3 3    72256699
# 4 4    27923459
# 5 5    14376126
# 6 6     9563395

# %%
library(ggplot2)

# %%
library(ggthemes)

# %%
p_M7 = ggplot(data = df_M7, aes(x=V1, y=V2)) + 
geom_line() +
#scale_x_continuous(expand = c(0, 0), limits = c(0,NA)) + 
#scale_y_continuous(expand = c(0, 0), limits = c(0, NA)) +
xlim(0, 200) + ylim(0, 2.5e+07) +
xlab("Coverage") + ylab("Frequency") +
geom_line(color="black", size = 0.2) +
theme_classic() +
theme(panel.border = element_blank(),
  panel.grid.major = element_blank(),
  panel.grid.minor = element_blank(),axis.line = element_line(colour = "black", size = 0.2)) +
#geom_vline(xintercept = 187, linetype = "dashed", color = "blue", size = 0.2) +
#geom_vline(xintercept = 93, linetype = "dashed", color = "blue", size = 0.2) +
#geom_vline(xintercept = 43, linetype = "dashed", color = "red", size = 0.2) +
#geom_vline(xintercept = 140, linetype = "dashed", color = "green", size = 0.2) +
#annotate("text", x = Inf, y = Inf, label = "A)", hjust = 0, vjust = 1, size = 5) +

geom_segment(x = 18, y = -2000000, xend = 18, yend = 22495610, linetype = "dashed", color = "magenta", size = 0.2) +
geom_segment(x = 37, y = -2000000, xend = 37, yend = 7509436, linetype = "dashed", color = "blue", size = 0.2) +
geom_segment(x = 72, y = -2000000, xend = 72, yend = 4884789, linetype = "dashed", color = "red", size = 0.2)
#geom_segment(x = 140, y = -2000000, xend = 140, yend = 1440842, linetype = "dashed", color = "green", size = 0.2)
#expand_limits(x = 0, y = 0)
ggsave(filename = "kmer_distribution.M7.png", p, dpi = 300, units = "in", device='png')
# Out:
# Saving 6.67 x 6.67 in image

# %%
df_Nui = read.table("/workspace/hrasrb/Blueberry_trio/data_qc/illumina/Nui_S2_L001_R1_001.fastq.gz_21mer_histogram.out", header = FALSE)

# %%
head(df_Nui)
# Out:
#   V1 V2
# 1 1  734699517
# 2 2  149823887
# 3 3   39316351
# 4 4   25844036
# 5 5   26141067
# 6 6   29464668

# %%
p_Nui = ggplot(data = df_Nui, aes(x=V1, y=V2)) + 
geom_line() +
#scale_x_continuous(expand = c(0, 0), limits = c(0,NA)) + 
#scale_y_continuous(expand = c(0, 0), limits = c(0, NA)) +
xlim(0, 200) + ylim(0, 4e+07) +
xlab("Coverage") + ylab("Frequency") +
geom_line(color="black", size = 0.2) +
theme_classic() +
theme(panel.border = element_blank(),
  panel.grid.major = element_blank(),
  panel.grid.minor = element_blank(),axis.line = element_line(colour = "black", size = 0.2)) +
#geom_vline(xintercept = 187, linetype = "dashed", color = "blue", size = 0.2) +
#geom_vline(xintercept = 93, linetype = "dashed", color = "blue", size = 0.2) +
#geom_vline(xintercept = 43, linetype = "dashed", color = "red", size = 0.2) +
#geom_vline(xintercept = 140, linetype = "dashed", color = "green", size = 0.2) +
#annotate("text", x = Inf, y = Inf, label = "A)", hjust = 0, vjust = 1, size = 5) +

geom_segment(x = 8, y = -2000000, xend = 8, yend = 34141494, linetype = "dashed", color = "magenta", size = 0.2) +
geom_segment(x = 32, y = -2000000, xend = 32, yend = 10353763, linetype = "dashed", color = "blue", size = 0.2)
#geom_segment(x = 72, y = -2000000, xend = 72, yend = 4884789, linetype = "dashed", color = "red", size = 0.2)
#geom_segment(x = 140, y = -2000000, xend = 140, yend = 1440842, linetype = "dashed", color = "green", size = 0.2)
#expand_limits(x = 0, y = 0)
ggsave(filename = "kmer_distribution.Nui.png", p, dpi = 300, units = "in", device='png')
# Out:
# Saving 6.67 x 6.67 in image

# %%
df_p = read.table("/workspace/hrasrb/Blueberry_trio/data_qc/hifi/kmer_analysis/progeny_combinedHiFi_Histogram.out", header = FALSE)

# %%
head(df_p)
# Out:
#   V1 V2
# 1 1    7015302
# 2 2  133858843
# 3 3   40403026
# 4 4   17806785
# 5 5   10211128
# 6 6    7501693

# %%
p_p = ggplot(data = df_p, aes(x=V1, y=V2)) + 
geom_line() +
#scale_x_continuous(expand = c(0, 0), limits = c(0,NA)) + 
#scale_y_continuous(expand = c(0, 0), limits = c(0, NA)) +
xlim(0, 200) + ylim(0, 2.5e+07) +
xlab("Coverage") + ylab("Frequency") +
geom_line(color="black", size = 0.2) +
theme_classic() +
theme(panel.border = element_blank(),
  panel.grid.major = element_blank(),
  panel.grid.minor = element_blank(),axis.line = element_line(colour = "black", size = 0.2)) +
#geom_vline(xintercept = 187, linetype = "dashed", color = "blue", size = 0.2) +
#geom_vline(xintercept = 93, linetype = "dashed", color = "blue", size = 0.2) +
#geom_vline(xintercept = 43, linetype = "dashed", color = "red", size = 0.2) +
#geom_vline(xintercept = 140, linetype = "dashed", color = "green", size = 0.2) +
#annotate("text", x = Inf, y = Inf, label = "A)", hjust = 0, vjust = 1, size = 5) +

geom_segment(x = 18, y = -2000000, xend = 18, yend = 22943787, linetype = "dashed", color = "magenta", size = 0.2) +
geom_segment(x = 38, y = -2000000, xend = 38, yend = 7651617, linetype = "dashed", color = "blue", size = 0.2) +
geom_segment(x = 57, y = -2000000, xend = 57, yend = 5449732, linetype = "dashed", color = "red", size = 0.2) +
geom_segment(x = 75, y = -2000000, xend = 75, yend = 4464653, linetype = "dashed", color = "green", size = 0.2)
#expand_limits(x = 0, y = 0)
ggsave(filename = "kmer_distribution.p.png", p, dpi = 300, units = "in", device='png')
# Out:
# Saving 6.67 x 6.67 in image

# %%
df_binM7 = read.table("/workspace/hrasrb/Blueberry_trio/rerun/2023-10-17_blueberry_hybrid/classified_M7_plus_unclassified/01_raw_data_QC/04_kmer/classified_M7_plus_unclassified.histo", header = FALSE)

# %%
p_binM7 = ggplot(data = df_binM7, aes(x=V1, y=V2)) + 
geom_line() +
#scale_x_continuous(expand = c(0, 0), limits = c(0,NA)) + 
#scale_y_continuous(expand = c(0, 0), limits = c(0, NA)) +
xlim(0, 200) + ylim(0, 2.5e+07) +
xlab("Coverage") + ylab("Frequency") +
geom_line(color="black", size = 0.2) +
theme_classic() +
theme(panel.border = element_blank(),
  panel.grid.major = element_blank(),
  panel.grid.minor = element_blank(),axis.line = element_line(colour = "black", size = 0.2)) +
#geom_vline(xintercept = 187, linetype = "dashed", color = "blue", size = 0.2) +
#geom_vline(xintercept = 93, linetype = "dashed", color = "blue", size = 0.2) +
#geom_vline(xintercept = 43, linetype = "dashed", color = "red", size = 0.2) +
#geom_vline(xintercept = 140, linetype = "dashed", color = "green", size = 0.2) +
#annotate("text", x = Inf, y = Inf, label = "A)", hjust = 0, vjust = 1, size = 5) +

geom_segment(x = 18, y = -2000000, xend = 18, yend = 21209154, linetype = "dashed", color = "magenta", size = 0.2) +
geom_segment(x = 35, y = -2000000, xend = 35, yend = 8938778, linetype = "dashed", color = "blue", size = 0.2)
#geom_segment(x = 57, y = -2000000, xend = 57, yend = 5449732, linetype = "dashed", color = "red", size = 0.2) +
#geom_segment(x = 75, y = -2000000, xend = 75, yend = 4464653, linetype = "dashed", color = "green", size = 0.2)
#expand_limits(x = 0, y = 0)
ggsave(filename = "kmer_distribution.binM7.png", p, dpi = 300, units = "in", device='png')
# Out:
# Saving 6.67 x 6.67 in image

# %%
df_binNui = read.table("/workspace/hrasrb/Blueberry_trio/rerun/2023-10-17_blueberry_hybrid/classified_Nui_plus_unclassified/01_raw_data_QC/04_kmer/classified_Nui_plus_unclassified.histo", header = FALSE)

# %%
p_binNui = ggplot(data = df_binNui, aes(x=V1, y=V2)) + 
geom_line() +
#scale_x_continuous(expand = c(0, 0), limits = c(0,NA)) + 
#scale_y_continuous(expand = c(0, 0), limits = c(0, NA)) +
xlim(0, 200) + ylim(0, 2.5e+07) +
xlab("Coverage") + ylab("Frequency") +
geom_line(color="black", size = 0.2) +
theme_classic() +
theme(panel.border = element_blank(),
  panel.grid.major = element_blank(),
  panel.grid.minor = element_blank(),axis.line = element_line(colour = "black", size = 0.2)) +
#geom_vline(xintercept = 187, linetype = "dashed", color = "blue", size = 0.2) +
#geom_vline(xintercept = 93, linetype = "dashed", color = "blue", size = 0.2) +
#geom_vline(xintercept = 43, linetype = "dashed", color = "red", size = 0.2) +
#geom_vline(xintercept = 140, linetype = "dashed", color = "green", size = 0.2) +
#annotate("text", x = Inf, y = Inf, label = "A)", hjust = 0, vjust = 1, size = 5) +

geom_segment(x = 18, y = -2000000, xend = 18, yend = 19979151, linetype = "dashed", color = "magenta", size = 0.2) +
geom_segment(x = 36, y = -2000000, xend = 36, yend = 9134398, linetype = "dashed", color = "blue", size = 0.2)
#geom_segment(x = 57, y = -2000000, xend = 57, yend = 5449732, linetype = "dashed", color = "red", size = 0.2) +
#geom_segment(x = 75, y = -2000000, xend = 75, yend = 4464653, linetype = "dashed", color = "green", size = 0.2)
#expand_limits(x = 0, y = 0)
ggsave(filename = "kmer_distribution.binNui.png", p, dpi = 300, units = "in", device='png')
# Out:
# Saving 6.67 x 6.67 in image

# %%
library(gridExtra)

# %%
p1 <- arrangeGrob(p_M7, top = "A")
p2 <- arrangeGrob(p_Nui, top = "B")
p3 <- arrangeGrob(p_p, top = "C")
p4 <- arrangeGrob(p_binM7, top = "D")
p5 <- arrangeGrob(p_binNui, top = "E")
p6 <- p

final_plot = grid.arrange(p1, p2, p3, p4, p5, p6, ncol = 3)

ggsave("output.png", final_plot, width = 15, height = 10, units = "in", dpi = 300)
# Out:
# Warning message:
# "Removed 9805 row(s) containing missing values (geom_path)."Warning message:
# "Removed 9805 row(s) containing missing values (geom_path)."Warning message:
# "Removed 9803 row(s) containing missing values (geom_path)."Warning message:
# "Removed 9803 row(s) containing missing values (geom_path)."Warning message:
# "Removed 9801 row(s) containing missing values (geom_path)."Warning message:
# "Removed 9801 row(s) containing missing values (geom_path)."Warning message:
# "Removed 18042 row(s) containing missing values (geom_path)."Warning message:
# "Removed 18042 row(s) containing missing values (geom_path)."Warning message:
# "Removed 25287 row(s) containing missing values (geom_path)."Warning message:
# "Removed 25287 row(s) containing missing values (geom_path)."
# plot without title

# %%
library(ggplot2)

# Create an empty plot with no data
p <- ggplot() +
  theme_void()  # Remove axis and background

# Create a data frame with text information
text_df <- data.frame(x = 0.5, y = 0.5, label = "A. Hortblue Petite\nB. Nui\nC. progeny\nD. partitioned progeny 'Hortblue Petite' set\nE. partitioned progeny 'Nui' set")

# Add text to the plot
p <- p + geom_text(data = text_df, aes(x = x, y = y, label = label), hjust = 0.5, vjust = 0.5)

# Show the plot
print(p)
# Out:
# plot without title

# %%
p
# Out:
# NULL

# %%
t
# Out:
# NULL
