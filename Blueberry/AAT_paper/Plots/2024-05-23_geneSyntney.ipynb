# %%
# !pip install pygenomeviz
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 7.0 MB/s eta 0:00:0000:010:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.1/3.1 MB 6.6 MB/s eta 0:00:0000:01:00:01m
# ...
#   WARNING: The scripts pgv-blast, pgv-download, pgv-gui, pgv-mmseqs, pgv-mummer and pgv-pmauve are installed in '/home/hraczw/.local/bin' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
# ...

# %%
from pygenomeviz import GenomeViz

#genome_list = [
#    dict(name="h1tg000296l_1", size=5200000, features=((4913939, 4916645, 1), (4964472, 4964939, 1), (4970363, 4972063, 1), (4984349, 4986872, 1), (5113260, 5115236, 1), (5132215, 5135066, 1), (5178171, 5179847, 1))),
#    dict(name="h2tg000453l_1", size=1000000, features=((202038, 203742, 1),(255945, 258646, 1),(286473, 288299, 1), (297102, 299782, 1), (357972, 358439, 1), (389289, 391292, 1), (400210, 401909, 1))),
#]

genome_list = [
    dict(name="HP_hA: h1tg000296l_1", size=300000, features=((4913939, 4916645, 1), (4964472, 4964939, 1), (4970363, 4972063, 1), (4984349, 4986872, 1), (5113260, 5115236, 1), (5132215, 5135066, 1), (5178171, 5179847, 1))),
    dict(name="HP_hB: h2tg000453l_1", size=300000, features=((202038, 203742, 1),(255945, 258646, 1),(286473, 288299, 1), (297102, 299782, 1), (357972, 358439, 1), (389289, 391292, 1), (400210, 401909, 1))),
    dict(name="Nui_hA: h1tg000862l_1", size=300000, features=((1530816, 1540082, 1), (1589288, 1591702, 1), (1625794, 1627470, 1))),
    dict(name="Nui_hB: h2tg000258l_1", size=300000, features=((1462460, 1465142, 1), (1513115, 1513582, 1), (1518919, 1520619, 1), (1533481, 1536008, 1)))
]

gv = GenomeViz(track_align_type="center")
#gv.set_scale_xticks(ymargin=0.5)

# Set multi tracks & features

index = 0
for genome in genome_list:
    name, size, features = genome["name"], genome["size"], genome["features"]
    #track = gv.add_feature_track(name, size)
    #track.add_sublabel()
    if index == 0:
        track = gv.add_feature_track(name, (4900000, 5200000))
        track.add_sublabel()
        for idx, feature in enumerate(features, 1):
            start, end, strand = feature
            track.add_feature(start, end, strand, plotstyle="bigarrow", lw = 0.1) # label=f"{idx:2d}", text_kws=dict(rotation=0, vpos="top", hpos="center"))
            track.add_feature(4964472, 4964939, 1, fc = "black", plotstyle="bigarrow", label="VcAAT7_t", text_kws=dict(rotation=30, vpos="top", hpos="center")) #label= "YFT", text_kws=dict(rotation=45, vpos="top", hpos="center"))
            track.add_feature(4984349, 4986872, 1, fc = "blue", plotstyle="bigarrow", label="VcAAT4_t", text_kws=dict(rotation=30, vpos="top", hpos="center")) #label= "SyGl", text_kws=dict(rotation=45, vpos="top", hpos="center"))
            track.add_feature(5132215, 5135066, 1, fc = "orange", plotstyle="bigarrow", label="VcAAT1b_t", text_kws=dict(rotation=30, vpos="top", hpos="center"))#, label= "FrBy", text_kws=dict(rotation=45, vpos="top", hpos="center"))
            track.add_feature(4913939, 4916645, 1, fc = "orange", plotstyle="bigarrow", label= "VcAAT1a*", text_kws=dict(rotation=30, vpos="top", hpos="center"))
            track.add_feature(4970363, 4972063, 1, fc = "green", plotstyle="bigarrow", label= "VcAAT2", text_kws=dict(rotation=30, vpos="top", hpos="center"))
            track.add_feature(5113260, 5115236, 1, fc = "red", plotstyle="bigarrow", label= "VcAAT3", text_kws=dict(rotation=30, vpos="top", hpos="center"))
            track.add_feature(5178171, 5179847, 1, fc = "fuchsia", plotstyle="bigarrow", label= "VcAAT5", text_kws=dict(rotation=30, vpos="top", hpos="center"))
            index = 1
    elif index == 1:
        track = gv.add_feature_track(name, (190000, 490000))
        track.add_sublabel()
        for idx, feature in enumerate(features, 1):
            start, end, strand = feature
            track.add_feature(start, end, strand, plotstyle="bigarrow", lw = 0.1) #, label=f"{idx:2d}", text_kws=dict(rotation=0, vpos="top", hpos="center"))
            track.add_feature(286473, 288299, 1, fc = "red", plotstyle="bigarrow", label="VcAAT3b_t", text_kws=dict(rotation=30, vpos="top", hpos="center"))#, label= "YFT", text_kws=dict(rotation=45, vpos="top", hpos="center"))
            track.add_feature(357972, 358439, 1, fc = "black", plotstyle="bigarrow", label="VcAAT7_t", text_kws=dict(rotation=30, vpos="top", hpos="center"))#, label= "SyGl", text_kws=dict(rotation=45, vpos="top", hpos="center"))
            track.add_feature(202038, 203742, 1, fc = "green", plotstyle="bigarrow", label= "VcAAT2a", text_kws=dict(rotation=30, vpos="top", hpos="center")) #VcAAT2 in initial Andrew's tests
            track.add_feature(255945, 258646, 1, fc = "orange", plotstyle="bigarrow", label= "VcAAT1a", text_kws=dict(rotation=30, vpos="top", hpos="center")) #VcAAT1 in initial Andrew's tests
            track.add_feature(297102, 299782, 1, fc = "orange", plotstyle="bigarrow", label= "VcAAT1b", text_kws=dict(rotation=30, vpos="top", hpos="center"))
            track.add_feature(389289, 391292, 1, fc = "red", plotstyle="bigarrow", label= "VcAAT3a", text_kws=dict(rotation=30, vpos="top", hpos="center")) # VcAAT3 in initial Andrew's tests
            track.add_feature(400210, 401909, 1, fc = "green", plotstyle="bigarrow", label= "VcAAT2b*", text_kws=dict(rotation=30, vpos="top", hpos="center"))

            #track.add_feature(471686, 472402, -1, fc = "blue", label= "FrBy", text_kws=dict(rotation=45, vpos="top", hpos="center"))
            index = 2
    elif index == 2:
        track = gv.add_feature_track(name, (1520000, 1820000))
        track.add_sublabel()
        for idx, feature in enumerate(features, 1):
            start, end, strand = feature
            track.add_feature(start, end, strand, plotstyle="bigarrow", lw = 0.1) #, label=f"{idx:2d}", text_kws=dict(rotation=0, vpos="top", hpos="center"))
            track.add_feature(1530816, 1540082, 1, fc = "brown", plotstyle="bigarrow", label="VcAAT6_t", text_kws=dict(rotation=30, vpos="top", hpos="center"))#, label= "YFT", text_kws=dict(rotation=45, vpos="top", hpos="center"))
            track.add_feature(1589288, 1591702, 1, fc = "orange", plotstyle="bigarrow", label= "VcAAT1", text_kws=dict(rotation=30, vpos="top", hpos="center"))
            track.add_feature(1625794, 1627470, 1, fc = "fuchsia", plotstyle="bigarrow", label= "VcAAT5", text_kws=dict(rotation=30, vpos="top", hpos="center"))
            index = 3
    elif index == 3:
        track = gv.add_feature_track(name, (1450000, 1750000))
        track.add_sublabel()
        for idx, feature in enumerate(features, 1):
            start, end, strand = feature
            track.add_feature(start, end, strand, plotstyle="bigarrow", lw = 0.1) #, label=f"{idx:2d}", text_kws=dict(rotation=0, vpos="top", hpos="center"))            
            track.add_feature(1513115, 1513582, 1, fc = "black", plotstyle="bigarrow", label="VcAAT7_t", text_kws=dict(rotation=30, vpos="top", hpos="center"))#, label= "YFT", text_kws=dict(rotation=45, vpos="top", hpos="center"))
            track.add_feature(1462460, 1465142, 1, fc = "orange", plotstyle="bigarrow", label= "VcAAT1", text_kws=dict(rotation=30, vpos="top", hpos="center"))
            track.add_feature(1518919, 1520619, 1, fc = "green", plotstyle="bigarrow", label= "VcAAT2", text_kws=dict(rotation=30, vpos="top", hpos="center"))
            track.add_feature(1533481, 1536008, 1, fc = "blue", plotstyle="bigarrow", label= "VcAAT4*", text_kws=dict(rotation=30, vpos="top", hpos="center"))
            #track.add_feature(471686, 472402, -1, fc = "blue", label= "FrBy", text_kws=dict(rotation=45, vpos="top", hpos="center"))


# Add links between "genome 01" and "genome 02"
#gv.add_link(("HP_hA", 13939, 16645), ("Nui_hB", 12460, 15142))
#gv.add_link(("ME02_01.v3", 1571197,1572859), ("P008ME_HAP2.2", 931085,932703))
#gv.add_link(("ME02_01.v3", 1778154,1778870), ("P008ME_HAP2.2", 471686, 472402))


#gv.add_link(("genome 01", 700, 500), ("genome 02", 900, 700))
#gv.add_link(("genome 01", 750, 950), ("genome 02", 1150, 950))
# Add links between "genome 02" and "genome 03"
#gv.add_link(("genome 02", 50, 200), ("genome 03", 150, 300), color="skyblue", inverted_color="lime", curve=True)
#gv.add_link(("genome 02", 350, 450), ("genome 03", 450, 350), color="skyblue", inverted_color="lime", curve=True)
#gv.add_link(("genome 02", 900, 700), ("genome 03", 700, 500), color="skyblue", inverted_color="lime", curve=True)
#gv.add_link(("genome 03", 900, 700), ("genome 02", 1150, 950), color="skyblue", inverted_color="lime", curve=True)

fig = gv.plotfig()
